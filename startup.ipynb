# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px
import sklearn

# %%
data = pd.read_csv('startUp(2).csv')
data.head()
# Out:
#    Unnamed: 0  R&D Spend  Administration  Marketing Spend       State  \
# 0           0  165349.20       136897.80        471784.10    New York
# 1           1  162597.70       151377.59        443898.53  California
# 2           2  153441.51       101145.55        407934.54     Florida
# 3           3  144372.41       118671.85        383199.62    New York
# 4           4  142107.34        91391.77        366168.42     Florida
#
#       Profit
# 0  192261.83
# 1  191792.06
# 2  191050.39
# 3  182901.99
# 4  166187.94

# %%
# state(text) is not linearly related to the profit(number)
df = data.copy()

df.drop(['State', 'Unnamed: 0'], axis = 1, inplace = True) # ..... Drop state becuase linear regression dont take text

# %%
stud = {'Gender': 'Male', 'name': 'Ehiz'}
stud['age'] = 5

stud
# Out:
# {'Gender': 'Male', 'name': 'Ehiz', 'age': 5}

# %%
scalers = {}

dz = df.copy()
from sklearn.preprocessing import StandardScaler
for i in df.drop(['Profit'], axis = 1).columns:
    scale = StandardScaler()
    dz[i] = scale.fit_transform(df[[i]])
    scalers[i+ '_scaled'] = scale

dz.head()
# Out:
#    R&D Spend  Administration  Marketing Spend     Profit
# 0   2.016411        0.560753         2.153943  192261.83
# 1   1.955860        1.082807         1.923600  191792.06
# 2   1.754364       -0.728257         1.626528  191050.39
# 3   1.554784       -0.096365         1.422210  182901.99
# 4   1.504937       -1.079919         1.281528  166187.94

# %%
for i in df.drop(['Profit'], axis = 1).columns:
# Out:
# {'R&D Spend_scaled': StandardScaler(),
#  'Administration_scaled': StandardScaler(),
#  'Marketing Spend_scaled': StandardScaler()}

# %%
# scalers
import joblib
joblib.dump(scalers['R&D Spend_scaled'], open('rd_spend_Scaler.pkl', 'wb'))
joblib.dump(scalers['Administration_scaled'], open('admin_Scaler.pkl', 'wb'))
joblib.dump(scalers['Marketing Spend_scaled'], open('mktExp_Scaler.pkl', 'wb'))

# %%
# df Preprocessing
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

for i in df.drop('Profit', axis = 1).columns:
    df[i] = scaler.fit_transform(df[[i]])

df.head()
# Out:
#    Unnamed: 0  R&D Spend  Administration  Marketing Spend     Profit
# 0   -1.697749   2.016411        0.560753         2.153943  192261.83
# 1   -1.628453   1.955860        1.082807         1.923600  191792.06
# 2   -1.559158   1.754364       -0.728257         1.626528  191050.39
# 3   -1.489862   1.554784       -0.096365         1.422210  182901.99
# 4   -1.420566   1.504937       -1.079919         1.281528  166187.94

# %%
def plotter(data, col1, col2, col3, col4):
    plt.figure(figsize = (12, 3))
    plt.subplot(1, 4, 1)
    sns.boxplot(x = data[col1])

    plt.subplot(1, 4, 2)
    sns.boxplot(x= data[col2])

    plt.subplot(1, 4, 3)
    sns.boxplot(x = data[col3])

    plt.subplot(1, 4, 4)
    sns.boxplot(x = data[col4])

# %%
from sklearn.model_selection import train_test_split

x = df.drop(['Profit', 'Unnamed: 0'], axis = 1)
y = df.Profit

xtrain, xtest, ytrain, ytest = train_test_split(x, y, test_size = 0.20, random_state = 7)
print(f'xtrain: {xtrain.shape}')
print(f'xtest: {xtest.shape}')
print('ytrain: {}'.format(ytrain.shape))
print('ytest: {}'.format(ytest.shape))
# Out:
# xtrain: (40, 3)
# xtest: (10, 3)
# ytrain: (40,)
# ytest: (10,)

# %%
train = pd.concat([xtrain, ytrain], axis = 1)
test = pd.concat([xtest, ytest], axis = 1)

print(f'Train Set')
display(train.head())

print(f'\n\nTest Set')
display(test.head())
# Out:
# Train Set
#     R&D Spend  Administration  Marketing Spend     Profit
# 32  -0.226949        0.283924        -1.362450   97427.84
# 46  -1.593413       -0.199322         0.711122   49490.75
# 34  -0.600682        1.310535        -0.001879   96712.80
# 18   0.396725       -0.258465         0.692992  124266.90
# 17   0.460720        0.855666         0.591017  125370.37
# Test Set
#     R&D Spend  Administration  Marketing Spend     Profit
# 13   0.402078        0.510179         0.343957  134307.35
# 15   0.897913        0.045868         0.419219  129917.04
# 22   0.006007        0.051850         0.762376  110352.25
# 42  -1.102106       -0.906938        -0.520596   71498.49
# 30  -0.258074       -0.205629        -0.990357   99937.59

# %%
# MODELLING ---
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score, mean_absolute_error

lin_reg = LinearRegression()
lin_reg.fit(xtrain, ytrain)
lin_reg
# Out:
# LinearRegression()

# %%
import joblib 
joblib.dump(lin_reg, open('startUpModel.pkl', 'wb'))

# %%
xtest
# Out:
#     R&D Spend  Administration  Marketing Spend
# 13   0.402078        0.510179         0.343957
# 15   0.897913        0.045868         0.419219
# 22   0.006007        0.051850         0.762376
# 42  -1.102106       -0.906938        -0.520596
# 30  -0.258074       -0.205629        -0.990357
# 27  -0.035519        0.235069         1.174271
# 1    1.955860        1.082807         1.923600
# 20   0.055726       -0.269588         0.723926
# 10   0.620398       -0.387599         0.149807
# 36  -0.991570        0.205925        -0.081763

# %%
lin_reg.predict([[0.402078,	0.510179	,0.343957]])
# Out:
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([127392.5230813])

# %%
ds = pd.read_csv(r'/Users/Ehiz/Documents/Data Science/DataSet/Loan_Data.csv')
ds.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# ...

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.linear_model import LogisticRegression

# %%
dx = df.copy()

steps = [('scaler', StandardScaler()),
         ('reg', LinearRegression())]

pipe = Pipeline(steps)

# %%
pipe.fit(xtrain, ytrain)
# Out:
# Pipeline(steps=[('scaler', StandardScaler()), ('reg', LinearRegression())])

# %%
pipe.predict(xtest)
# Out:
# array([127392.50772254, 146385.70068084, 114488.6516408 ,  70069.50013309,
#         99183.09336759, 114147.4957099 , 189607.88655407, 116474.03016545,
#        135594.49422973,  74662.2701519 ])

# %%
from sklearn.impute import SimpleImputer

num = Pipeline(steps = [
               ('impute_mean', SimpleImputer(strategy= 'mean')),
                ('scale', StandardScaler())])

cat = Pipeline(steps = [
                    ('impute_mode', SimpleImputer(strategy = 'most_frequent')),
                    ('encode', OneHotEncoder(handle_unknown= 'ignore'))
])

# %%
# combine both processors 
from sklearn.compose import ColumnTransformer

prepro = ColumnTransformer(
    [('cats', cat, [i for i in ds.drop(['Loan_Status', 'Loan_ID'], axis = 1).select_dtypes(exclude = 'number').columns]),
     ('nums', num, [i for i in ds.drop(['Loan_Status', 'Loan_ID'], axis = 1).select_dtypes(include = 'number').columns])]
)
prepro
# Out:
# ColumnTransformer(transformers=[('cats',
#                                  Pipeline(steps=[('impute_mode',
#                                                   SimpleImputer(strategy='most_frequent')),
#                                                  ('encode',
#                                                   OneHotEncoder(handle_unknown='ignore'))]),
#                                  ['Gender', 'Married', 'Dependents',
#                                   'Education', 'Self_Employed',
#                                   'Property_Area']),
#                                 ('nums',
#                                  Pipeline(steps=[('impute_mean',
#                                                   SimpleImputer()),
#                                                  ('scale', StandardScaler())]),
#                                  ['ApplicantIncome', 'CoapplicantIncome',
#                                   'LoanAmount', 'Loan_Amount_Term',
# ...

# %%
from sklearn.pipeline import make_pipeline

pipes = make_pipeline(prepro, LogisticRegression())
pipes
# Out:
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(transformers=[('cats',
#                                                   Pipeline(steps=[('impute_mode',
#                                                                    SimpleImputer(strategy='most_frequent')),
#                                                                   ('encode',
#                                                                    OneHotEncoder(handle_unknown='ignore'))]),
#                                                   ['Gender', 'Married',
#                                                    'Dependents', 'Education',
#                                                    'Self_Employed',
#                                                    'Property_Area']),
#                                                  ('nums',
#                                                   Pipeline(steps=[('impute_mean',
# ...

# %%
xx = ds.drop(['Loan_Status', 'Loan_ID'], axis = 1)
yy = ds.Loan_Status

xtrain, xtest, ytrain, ytest = train_test_split(xx, yy, test_size = 0.20, random_state = 7)

# %%
pipes.fit(xtrain, ytrain)
# ds.head()
# Out:
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(transformers=[('cats',
#                                                   Pipeline(steps=[('impute_mode',
#                                                                    SimpleImputer(strategy='most_frequent')),
#                                                                   ('encode',
#                                                                    OneHotEncoder(handle_unknown='ignore'))]),
#                                                   ['Gender', 'Married',
#                                                    'Dependents', 'Education',
#                                                    'Self_Employed',
#                                                    'Property_Area']),
#                                                  ('nums',
#                                                   Pipeline(steps=[('impute_mean',
# ...

# %%
pred = pipes.predict(xtest)
predicted = pd.Series(pred)
pd.concat([ytest.reset_index(drop = True), predicted], axis = 1)
# Out:
#     Loan_Status  0
# 0             N  N
# 1             Y  Y
# 2             N  N
# 3             Y  Y
# 4             Y  Y
# ..          ... ..
# 118           N  N
# 119           Y  Y
# 120           Y  Y
# 121           Y  Y
# 122           Y  Y
#
# [123 rows x 2 columns]
